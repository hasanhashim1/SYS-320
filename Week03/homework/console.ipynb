# %% [markdown]
# # URLHAUS

# %%
import urlHaus as u
import importlib
importlib.reload(u)
# Out:
# <module 'urlHaus' from 'c:\\Users\\Hasan\\Desktop\\Champlain classes\\SYS-320\\SYS-320\\Week03\\homework\\urlHaus.py'>

# %%
u.urlHausOpen('../../logs/urlHaus.csv', ['.edu','.gov'])
# Out:
# URL: hxxp://lutanedukasi.co.id/wp-includes/O.exe
# Info: None
# ************************************************************
#
# URL: hxxp://ayoobeducationaltrust.in/cms/LmOOeDnNo0dh4vkN/
# Info: 2022-01-31 03:XX:XX
# ************************************************************
#
# URL: hxxps://grabovoi.education/wp-includes/QONu3Rk/
# Info: 2022-01-27 20:XX:XX
# ************************************************************
#
# URL: hxxps://historybanks.net/wp-content/themes/edulite/lib/upgrade/presbyopia.php
# Info: 2022-01-27 05:XX:XX
# ************************************************************
#
# URL: hxxp://mitt.edu.in/cuban.php
# Info: 2022-01-28 15:XX:XX
# ************************************************************
#
# URL: hxxp://mitt.edu.in/splotched.php
# Info: 2022-01-28 15:XX:XX
# ************************************************************
#
# URL: hxxps://forms.saurashtrauniversity.edu/belt.php
# Info: None
# ...

# %%
u.urlHausOpen('../../logs/urlHaus.csv', ['win32'])
# Out:
# URL: hxxp://103.171.0.134/Registry/.win32.exe
# Info: None
# ************************************************************
#
# URL: hxxp://198.46.132.195/Registry/.win32.exe
# Info: None
# ************************************************************
#
# URL: hxxp://103.89.90.10/Registry/.win32.exe
# Info: None
# ************************************************************
#
# URL: hxxp://103.171.0.134/googleCRC/.win32.exe
# Info: None
# ************************************************************
#
# URL: hxxp://198.46.132.195/googleCRC/.win32.exe
# Info: None
# ************************************************************
#
# URL: hxxp://103.171.0.134/glcouldB2/.win32.exe
# Info: None
# ************************************************************
#
# URL: hxxp://103.171.0.134/couldA9/.win32.exe
# Info: None
# ************************************************************
#
# URL: hxxp://103.89.90.10/couldA9/.win32.exe
# Info: None
# ...

# %% [markdown]
# ### Part ll

# %% [markdown]
# 1. Provide the URL to the CSV documentation on the Python website. Ensure you select the site with the appropriate version of Python you are using.
#
# https://realpython.com/python-csv/
#
# 2. What option is used if the default delimiter is not a comma? Write the full syntax. Example csv.function(option=x, option2=y)
#  https://www.geeksforgeeks.org/working-csv-files-python/
# csvReader = csv.reader(csvfile, delimiter=',')
#
# 3. In a CSV file that uses a comma as a delimiter, there may be a field with a comma within it. What option does Python provide to escape the comma within the text of a field so it is differentiated with the comma as a field delimiter? Write the full syntax. Example csv.function(option=x, option2=y) 4
#
# csvReader = csv.reader(csvfile, delimiter=',', quotechar='^'
#
# 4. What is the purpose of heredocs in Python?
#
# The purpose of the herdocs is to use a specifiying  block and so many whitespace inside the text.
# https://devcamp.com/trails/28/campsites/213/guides/guide-heredocs-python
#
# 5. What did you like the most and least about this assignment?
#
# One of the things I liked the most was using Python to fetch data from the CSV file. The one thing I didn't like was debugging. Debugging is tough for me because I didn't write the code, so I don't know what a programmer is thinking.
